# %%
import os
import xml.etree.ElementTree as ET
import shutil
import random

# %%
# Pastikan folder tersedia
extract_dir = './dataset'

# %%
# Path tujuan untuk training dan testing
train_folder = os.path.join(extract_dir, 'train')
valid_folder = os.path.join(extract_dir, 'valid')
test_folder = os.path.join(extract_dir, 'test')


# Filter hanya file gambar dan label
image_files = [f for f in os.listdir(test_folder) if os.path.splitext(f)[1].lower() in {".jpg", ".jpeg", ".png"}]
label_files = [f for f in os.listdir(test_folder) if os.path.splitext(f)[1].lower() in {".xml", ".txt"}]

if len(image_files) != len(label_files):
    raise ValueError("Jumlah file gambar dan label tidak sesuai. Harap periksa dataset.")

# Mengurutkan agar pasangan file tetap sesuai
image_files.sort()
label_files.sort()

# Gabungkan file gambar dan label
paired_files = list(zip(image_files, label_files))

# Acak pasangan file
random.seed(42)  # Untuk hasil yang reproducible
random.shuffle(paired_files)

# Hitung jumlah data untuk training dan testing
split_index = int(0.7 * len(paired_files))

train_files = paired_files[:split_index]
valid_files = paired_files[split_index:]

# Fungsi untuk memindahkan file
def move_files(file_pairs, source_folder, target_folder):
    for img_file, label_file in file_pairs:
        shutil.move(os.path.join(source_folder, img_file), os.path.join(target_folder, img_file))
        shutil.move(os.path.join(source_folder, label_file), os.path.join(target_folder, label_file))

# Pindahkan file ke folder training dan validation
move_files(train_files, test_folder, train_folder)
move_files(valid_files, test_folder, valid_folder)


print(f"Data berhasil dibagi: {len(train_files)} untuk training, {len(valid_files)} untuk testing.")
# Out:
# Data berhasil dibagi: 53 untuk training, 24 untuk testing.

# %%
folder_prefix_map = {
    "train": "train",
    "valid": "valid"
}

image_extensions = {".jpg", ".jpeg", ".png"}
label_extensions = {".xml", ".txt"}

# Daftar label yang akan digunakan
allowed_labels = {'struk_belanja'}

for folder, prefix in folder_prefix_map.items():
    folder_path = os.path.join(extract_dir, folder)
    if os.path.exists(folder_path):
        image_counter = 1
        label_counter = 1
        
        file_map = {}
        
        # Mencari pasangan file gambar dan label
        for filename in sorted(os.listdir(folder_path)):
            name, ext = os.path.splitext(filename)
            if ext in image_extensions or ext in label_extensions:
                if name not in file_map:
                    file_map[name] = {}
                file_map[name][ext] = filename
        
        for base_name, files in file_map.items():
            new_image_filename = ""
            # Rename gambar
            if any(ext in files for ext in image_extensions):
                old_image_filename = next(files[ext] for ext in image_extensions if ext in files)
                new_image_filename = f"{prefix}_image_{image_counter}{os.path.splitext(old_image_filename)[1]}"
                os.rename(os.path.join(folder_path, old_image_filename), os.path.join(folder_path, new_image_filename))
                print(f"Renamed: {old_image_filename} -> {new_image_filename}")
                image_counter += 1
            
            # Rename label
            if any(ext in files for ext in label_extensions):
                old_label_filename = next(files[ext] for ext in label_extensions if ext in files)
                new_label_filename = f"{prefix}_label_{label_counter}{os.path.splitext(old_label_filename)[1]}"
                old_label_path = os.path.join(folder_path, old_label_filename)
                new_label_path = os.path.join(folder_path, new_label_filename)
                
                os.rename(old_label_path, new_label_path)
                print(f"Renamed: {old_label_filename} -> {new_label_filename}")

                # Update isi XML dan filter label
                if new_label_filename.endswith(".xml"):
                    tree = ET.parse(new_label_path)
                    root = tree.getroot()

                    # Update elemen <filename> dan <path>
                    if root.find("filename") is not None:
                        root.find("filename").text = new_image_filename
                    if root.find("path") is not None:
                        root.find("path").text = new_image_filename
                    
                    # Filter label yang tidak diinginkan
                    for obj in root.findall('object'):
                        label = obj.find('name').text
                        if label not in allowed_labels:
                            root.remove(obj)
                    
                    # Simpan file XML yang sudah difilter
                    tree.write(new_label_path)
                    print(f"Filtered and updated XML: {new_label_filename}")
                
                label_counter += 1
    else:
        print(f"Folder {folder_path} tidak ditemukan.")
# Out:
# Renamed: 0_jpg.rf.edfc36b893bb5852b605b16fba630ac5.jpg -> train_image_1.jpg
# Renamed: 0_jpg.rf.edfc36b893bb5852b605b16fba630ac5.xml -> train_label_1.xml
# Filtered and updated XML: train_label_1.xml
# Renamed: 100_jpg.rf.c788257ba5f3206ce8d9f20e2afe5bed.jpg -> train_image_2.jpg
# Renamed: 100_jpg.rf.c788257ba5f3206ce8d9f20e2afe5bed.xml -> train_label_2.xml
# Filtered and updated XML: train_label_2.xml
# Renamed: 10210397_20180607101646_jpg.rf.f4a2894bbb2936c1232f6f79d1dbe895.jpg -> train_image_3.jpg
# Renamed: 10210397_20180607101646_jpg.rf.f4a2894bbb2936c1232f6f79d1dbe895.xml -> train_label_3.xml
# Filtered and updated XML: train_label_3.xml
# Renamed: 102_jpg.rf.d401759ffa3b36cceac4810d7d067ad6.jpg -> train_image_4.jpg
# Renamed: 102_jpg.rf.d401759ffa3b36cceac4810d7d067ad6.xml -> train_label_4.xml
# Filtered and updated XML: train_label_4.xml
# Renamed: 105_jpg.rf.d49d24d0e291ed9aae619cf692273ac4.jpg -> train_image_5.jpg
# Renamed: 105_jpg.rf.d49d24d0e291ed9aae619cf692273ac4.xml -> train_label_5.xml
# Filtered and updated XML: train_label_5.xml
# Renamed: 108_jpg.rf.707d6d35667b2805ed3896c043562fb0.jpg -> train_image_6.jpg
# Renamed: 108_jpg.rf.707d6d35667b2805ed3896c043562fb0.xml -> train_label_6.xml
# Filtered and updated XML: train_label_6.xml
# Renamed: 109_jpg.rf.8a34adb9844acea80812343009139016.jpg -> train_image_7.jpg
# Renamed: 109_jpg.rf.8a34adb9844acea80812343009139016.xml -> train_label_7.xml
# Filtered and updated XML: train_label_7.xml
# Renamed: 10_jpg.rf.7199ba92c383f872b42c39c333746028.jpg -> train_image_8.jpg
# Renamed: 10_jpg.rf.7199ba92c383f872b42c39c333746028.xml -> train_label_8.xml
# Filtered and updated XML: train_label_8.xml
# Renamed: 110_jpg.rf.5218db89a7501e0e5690ab3567a40c02.jpg -> train_image_9.jpg
# Renamed: 110_jpg.rf.5218db89a7501e0e5690ab3567a40c02.xml -> train_label_9.xml
# Filtered and updated XML: train_label_9.xml
# Renamed: 111_jpg.rf.76dbdb2c4aa07011d9c3e3b90a78917e.jpg -> train_image_10.jpg
# Renamed: 111_jpg.rf.76dbdb2c4aa07011d9c3e3b90a78917e.xml -> train_label_10.xml
# Filtered and updated XML: train_label_10.xml
# Renamed: 112_jpg.rf.fd121a69162ca7107a1072a6328c37ea.jpg -> train_image_11.jpg
# Renamed: 112_jpg.rf.fd121a69162ca7107a1072a6328c37ea.xml -> train_label_11.xml
# Filtered and updated XML: train_label_11.xml
# Renamed: 114_jpg.rf.b1cc8f2ed388763b611ee8cdd857dfcf.jpg -> train_image_12.jpg
# Renamed: 114_jpg.rf.b1cc8f2ed388763b611ee8cdd857dfcf.xml -> train_label_12.xml
# Filtered and updated XML: train_label_12.xml
# Renamed: 116_jpg.rf.6511ccaeca7e3c42805ab77b13a0411c.jpg -> train_image_13.jpg
# Renamed: 116_jpg.rf.6511ccaeca7e3c42805ab77b13a0411c.xml -> train_label_13.xml
# Filtered and updated XML: train_label_13.xml
# Renamed: 120_jpg.rf.da71a6e4aac882a01a4cdebffa1446ae.jpg -> train_image_14.jpg
# Renamed: 120_jpg.rf.da71a6e4aac882a01a4cdebffa1446ae.xml -> train_label_14.xml
# Filtered and updated XML: train_label_14.xml
# Renamed: 122_jpg.rf.fea0c996f53312fbca9dfa4158cf0849.jpg -> train_image_15.jpg
# Renamed: 122_jpg.rf.fea0c996f53312fbca9dfa4158cf0849.xml -> train_label_15.xml
# Filtered and updated XML: train_label_15.xml
# Renamed: 127_jpg.rf.e8d856ebf29be5a4fa73d91c247e5e31.jpg -> train_image_16.jpg
# Renamed: 127_jpg.rf.e8d856ebf29be5a4fa73d91c247e5e31.xml -> train_label_16.xml
# Filtered and updated XML: train_label_16.xml
# Renamed: 128_jpg.rf.ae7e7e46b75fa4432b0aa54f63bb0ae2.jpg -> train_image_17.jpg
# Renamed: 128_jpg.rf.ae7e7e46b75fa4432b0aa54f63bb0ae2.xml -> train_label_17.xml
# Filtered and updated XML: train_label_17.xml
# Renamed: 12_jpg.rf.1c394b1ee275e204ba2f6d7c02bb4276.jpg -> train_image_18.jpg
# Renamed: 12_jpg.rf.1c394b1ee275e204ba2f6d7c02bb4276.xml -> train_label_18.xml
# Filtered and updated XML: train_label_18.xml
# Renamed: 130_jpg.rf.78bc42cb4290c9ca6199ff35f5ea4f2b.jpg -> train_image_19.jpg
# Renamed: 130_jpg.rf.78bc42cb4290c9ca6199ff35f5ea4f2b.xml -> train_label_19.xml
# Filtered and updated XML: train_label_19.xml
# Renamed: 131_jpg.rf.9482a47a7431493dc1fa5eb6e32b23fb.jpg -> train_image_20.jpg
# Renamed: 131_jpg.rf.9482a47a7431493dc1fa5eb6e32b23fb.xml -> train_label_20.xml
# Filtered and updated XML: train_label_20.xml
# Renamed: 133_jpg.rf.3f7578561815f7d88694a1daa50b9493.jpg -> train_image_21.jpg
# Renamed: 133_jpg.rf.3f7578561815f7d88694a1daa50b9493.xml -> train_label_21.xml
# Filtered and updated XML: train_label_21.xml
# Renamed: 134_jpg.rf.a83653f2b8bda26cbc6588192603ab95.jpg -> train_image_22.jpg
# Renamed: 134_jpg.rf.a83653f2b8bda26cbc6588192603ab95.xml -> train_label_22.xml
# Filtered and updated XML: train_label_22.xml
# Renamed: 135_jpg.rf.49f34c6a7bf71cd4b0d16da50b4b3597.jpg -> train_image_23.jpg
# Renamed: 135_jpg.rf.49f34c6a7bf71cd4b0d16da50b4b3597.xml -> train_label_23.xml
# Filtered and updated XML: train_label_23.xml
# Renamed: 136_jpg.rf.e45a52704948798c23fe98d09b2c48cf.jpg -> train_image_24.jpg
# Renamed: 136_jpg.rf.e45a52704948798c23fe98d09b2c48cf.xml -> train_label_24.xml
# Filtered and updated XML: train_label_24.xml
# Renamed: 137_jpg.rf.5557c54dca329ad5af0b0f68c9e716d6.jpg -> train_image_25.jpg
# Renamed: 137_jpg.rf.5557c54dca329ad5af0b0f68c9e716d6.xml -> train_label_25.xml
# Filtered and updated XML: train_label_25.xml
# Renamed: 13_jpg.rf.90cc20572dc0f565b19f771241293c72.jpg -> train_image_26.jpg
# Renamed: 13_jpg.rf.90cc20572dc0f565b19f771241293c72.xml -> train_label_26.xml
# Filtered and updated XML: train_label_26.xml
# Renamed: 140_jpg.rf.cee7444453c3d87b077f3a199d5d5ad6.jpg -> train_image_27.jpg
# Renamed: 140_jpg.rf.cee7444453c3d87b077f3a199d5d5ad6.xml -> train_label_27.xml
# Filtered and updated XML: train_label_27.xml
# Renamed: 141_jpg.rf.3bec3893fd1ba4c6695958deac01aff8.jpg -> train_image_28.jpg
# Renamed: 141_jpg.rf.3bec3893fd1ba4c6695958deac01aff8.xml -> train_label_28.xml
# Filtered and updated XML: train_label_28.xml
# Renamed: 142_jpg.rf.cea7b2da6c2b7be3709d946c81997fc5.jpg -> train_image_29.jpg
# Renamed: 142_jpg.rf.cea7b2da6c2b7be3709d946c81997fc5.xml -> train_label_29.xml
# Filtered and updated XML: train_label_29.xml
# Renamed: 146_jpg.rf.8c9a4517687280644651a836bb2dc86b.jpg -> train_image_30.jpg
# Renamed: 146_jpg.rf.8c9a4517687280644651a836bb2dc86b.xml -> train_label_30.xml
# Filtered and updated XML: train_label_30.xml
# Renamed: 147_jpg.rf.1bd128516357efb96b00b93daab297fa.jpg -> train_image_31.jpg
# Renamed: 147_jpg.rf.1bd128516357efb96b00b93daab297fa.xml -> train_label_31.xml
# Filtered and updated XML: train_label_31.xml
# Renamed: 148_jpg.rf.912350b61fd581c64f5ed559578ff235.jpg -> train_image_32.jpg
# Renamed: 148_jpg.rf.912350b61fd581c64f5ed559578ff235.xml -> train_label_32.xml
# Filtered and updated XML: train_label_32.xml
# Renamed: 149_jpg.rf.4e7602f9b19dcd758a4a122f00a2e363.jpg -> train_image_33.jpg
# Renamed: 149_jpg.rf.4e7602f9b19dcd758a4a122f00a2e363.xml -> train_label_33.xml
# Filtered and updated XML: train_label_33.xml
# Renamed: 14_jpg.rf.a84ca72e1cad477b229c4cadd521748d.jpg -> train_image_34.jpg
# Renamed: 14_jpg.rf.a84ca72e1cad477b229c4cadd521748d.xml -> train_label_34.xml
# Filtered and updated XML: train_label_34.xml
# Renamed: 150_jpg.rf.ec9d45a16c224285219185188ab7f20f.jpg -> train_image_35.jpg
# Renamed: 150_jpg.rf.ec9d45a16c224285219185188ab7f20f.xml -> train_label_35.xml
# Filtered and updated XML: train_label_35.xml
# Renamed: 153_jpg.rf.da06e7444d0a5819bb9a054f051a5e37.jpg -> train_image_36.jpg
# Renamed: 153_jpg.rf.da06e7444d0a5819bb9a054f051a5e37.xml -> train_label_36.xml
# Filtered and updated XML: train_label_36.xml
# Renamed: 156_jpg.rf.348eb6f3729ec81f25a16983db33b28e.jpg -> train_image_37.jpg
# Renamed: 156_jpg.rf.348eb6f3729ec81f25a16983db33b28e.xml -> train_label_37.xml
# Filtered and updated XML: train_label_37.xml
# Renamed: 157_jpg.rf.74711c4f52418174101d9f9382e9092b.jpg -> train_image_38.jpg
# Renamed: 157_jpg.rf.74711c4f52418174101d9f9382e9092b.xml -> train_label_38.xml
# Filtered and updated XML: train_label_38.xml
# Renamed: 159_jpg.rf.04765092afe796fbf3e4ac0204d534b5.jpg -> train_image_39.jpg
# Renamed: 159_jpg.rf.04765092afe796fbf3e4ac0204d534b5.xml -> train_label_39.xml
# Filtered and updated XML: train_label_39.xml
# Renamed: 15_jpg.rf.102a90443d2186d72ae1ae34bc922530.jpg -> train_image_40.jpg
# Renamed: 15_jpg.rf.102a90443d2186d72ae1ae34bc922530.xml -> train_label_40.xml
# Filtered and updated XML: train_label_40.xml
# Renamed: 15_jpg.rf.1bf3f4b7a8399fa14594f27e13f49e10.jpg -> train_image_41.jpg
# Renamed: 15_jpg.rf.1bf3f4b7a8399fa14594f27e13f49e10.xml -> train_label_41.xml
# Filtered and updated XML: train_label_41.xml
# Renamed: 162_jpg.rf.30bce521e445332648f0ed529ce8894c.jpg -> train_image_42.jpg
# Renamed: 162_jpg.rf.30bce521e445332648f0ed529ce8894c.xml -> train_label_42.xml
# Filtered and updated XML: train_label_42.xml
# Renamed: 163_jpg.rf.a3eb8ec209302fcac00509ebe829da4b.jpg -> train_image_43.jpg
# Renamed: 163_jpg.rf.a3eb8ec209302fcac00509ebe829da4b.xml -> train_label_43.xml
# Filtered and updated XML: train_label_43.xml
# Renamed: 164_jpg.rf.eaba1274586e780a5f1bb83441c4e98d.jpg -> train_image_44.jpg
# Renamed: 164_jpg.rf.eaba1274586e780a5f1bb83441c4e98d.xml -> train_label_44.xml
# Filtered and updated XML: train_label_44.xml
# Renamed: 165_jpg.rf.33d52221abf1e0d7b07fa4ee0a6858eb.jpg -> train_image_45.jpg
# Renamed: 165_jpg.rf.33d52221abf1e0d7b07fa4ee0a6858eb.xml -> train_label_45.xml
# Filtered and updated XML: train_label_45.xml
# Renamed: 166_jpg.rf.e5c0793c802169103a9bfb0fecc38690.jpg -> train_image_46.jpg
# Renamed: 166_jpg.rf.e5c0793c802169103a9bfb0fecc38690.xml -> train_label_46.xml
# Filtered and updated XML: train_label_46.xml
# Renamed: 16_jpg.rf.3def99f1f889bed1c593b53f75b9a696.jpg -> train_image_47.jpg
# Renamed: 16_jpg.rf.3def99f1f889bed1c593b53f75b9a696.xml -> train_label_47.xml
# Filtered and updated XML: train_label_47.xml
# Renamed: 16_jpg.rf.d13b7fdc5b6a6805e770528778620180.jpg -> train_image_48.jpg
# Renamed: 16_jpg.rf.d13b7fdc5b6a6805e770528778620180.xml -> train_label_48.xml
# Filtered and updated XML: train_label_48.xml
# Renamed: 19_jpg.rf.4ee1ee192e219478121c8bc8a1c68c0e.jpg -> train_image_49.jpg
# Renamed: 19_jpg.rf.4ee1ee192e219478121c8bc8a1c68c0e.xml -> train_label_49.xml
# Filtered and updated XML: train_label_49.xml
# Renamed: 19_jpg.rf.e2903b4a083371fd0a92c34a3950f2a5.jpg -> train_image_50.jpg
# Renamed: 19_jpg.rf.e2903b4a083371fd0a92c34a3950f2a5.xml -> train_label_50.xml
# Filtered and updated XML: train_label_50.xml
# Renamed: 1_jpg.rf.2785c52f1984c76139fabf26559e42a5.jpg -> train_image_51.jpg
# Renamed: 1_jpg.rf.2785c52f1984c76139fabf26559e42a5.xml -> train_label_51.xml
# Filtered and updated XML: train_label_51.xml
# Renamed: 20_jpg.rf.9be027f99935a8b615c0356e32fc4d32.jpg -> train_image_52.jpg
# Renamed: 20_jpg.rf.9be027f99935a8b615c0356e32fc4d32.xml -> train_label_52.xml
# Filtered and updated XML: train_label_52.xml
# Renamed: 23_jpg.rf.3c02199fa30d69d816f29960c9f69bf5.jpg -> train_image_53.jpg
# Renamed: 23_jpg.rf.3c02199fa30d69d816f29960c9f69bf5.xml -> train_label_53.xml
# Filtered and updated XML: train_label_53.xml
# Renamed: 25_jpg.rf.fdb7528cb7fa01865c6ac03ccdbae3c2.jpg -> train_image_54.jpg
# Renamed: 25_jpg.rf.fdb7528cb7fa01865c6ac03ccdbae3c2.xml -> train_label_54.xml
# Filtered and updated XML: train_label_54.xml
# Renamed: 26_jpg.rf.d9676bae6fcb157ad78d3ef057a99122.jpg -> train_image_55.jpg
# Renamed: 26_jpg.rf.d9676bae6fcb157ad78d3ef057a99122.xml -> train_label_55.xml
# Filtered and updated XML: train_label_55.xml
# Renamed: 28_jpg.rf.0635457ab775800f12e2f4b8af8b9914.jpg -> train_image_56.jpg
# Renamed: 28_jpg.rf.0635457ab775800f12e2f4b8af8b9914.xml -> train_label_56.xml
# Filtered and updated XML: train_label_56.xml
# Renamed: 29_jpg.rf.506127f64dca9124a899cc18a3e31833.jpg -> train_image_57.jpg
# Renamed: 29_jpg.rf.506127f64dca9124a899cc18a3e31833.xml -> train_label_57.xml
# Filtered and updated XML: train_label_57.xml
# Renamed: 2_jpg.rf.89b5168f00b115f18bbe8690852d0956.jpg -> train_image_58.jpg
# Renamed: 2_jpg.rf.89b5168f00b115f18bbe8690852d0956.xml -> train_label_58.xml
# Filtered and updated XML: train_label_58.xml
# Renamed: 31_jpg.rf.d7bae8a72b486dd0bd26c64618f94e4e.jpg -> train_image_59.jpg
# Renamed: 31_jpg.rf.d7bae8a72b486dd0bd26c64618f94e4e.xml -> train_label_59.xml
# Filtered and updated XML: train_label_59.xml
# Renamed: 32_jpg.rf.160b21dd302083b3df36869ca45584f0.jpg -> train_image_60.jpg
# Renamed: 32_jpg.rf.160b21dd302083b3df36869ca45584f0.xml -> train_label_60.xml
# Filtered and updated XML: train_label_60.xml
# Renamed: 34_jpg.rf.fe333c79d984a3bc0ea6d24b9d278977.jpg -> train_image_61.jpg
# Renamed: 34_jpg.rf.fe333c79d984a3bc0ea6d24b9d278977.xml -> train_label_61.xml
# Filtered and updated XML: train_label_61.xml
# Renamed: 36_jpg.rf.80541a43b7b4defc1fc5c31fcc22945b.jpg -> train_image_62.jpg
# Renamed: 36_jpg.rf.80541a43b7b4defc1fc5c31fcc22945b.xml -> train_label_62.xml
# Filtered and updated XML: train_label_62.xml
# Renamed: 38_jpg.rf.13ed11f8d206f036eacca1d8e641e0ee.jpg -> train_image_63.jpg
# Renamed: 38_jpg.rf.13ed11f8d206f036eacca1d8e641e0ee.xml -> train_label_63.xml
# Filtered and updated XML: train_label_63.xml
# Renamed: 3_jpg.rf.29b5218eb2fd4ca93378cdcf6ead4937.jpg -> train_image_64.jpg
# Renamed: 3_jpg.rf.29b5218eb2fd4ca93378cdcf6ead4937.xml -> train_label_64.xml
# Filtered and updated XML: train_label_64.xml
# Renamed: 44_jpg.rf.0744683b3e72a70921ee0097562d56c9.jpg -> train_image_65.jpg
# Renamed: 44_jpg.rf.0744683b3e72a70921ee0097562d56c9.xml -> train_label_65.xml
# Filtered and updated XML: train_label_65.xml
# Renamed: 45_jpg.rf.c2fd76bb1055f25aab99c2bc0717540e.jpg -> train_image_66.jpg
# Renamed: 45_jpg.rf.c2fd76bb1055f25aab99c2bc0717540e.xml -> train_label_66.xml
# Filtered and updated XML: train_label_66.xml
# Renamed: 48_jpg.rf.a3f7b6724ac293b9f31e890af5261145.jpg -> train_image_67.jpg
# Renamed: 48_jpg.rf.a3f7b6724ac293b9f31e890af5261145.xml -> train_label_67.xml
# Filtered and updated XML: train_label_67.xml
# Renamed: 49_jpg.rf.21386c668877594d6cf1b1f33283776d.jpg -> train_image_68.jpg
# Renamed: 49_jpg.rf.21386c668877594d6cf1b1f33283776d.xml -> train_label_68.xml
# Filtered and updated XML: train_label_68.xml
# Renamed: 4_jpeg.rf.711606a0299f7af4845c212855070683.jpg -> train_image_69.jpg
# Renamed: 4_jpeg.rf.711606a0299f7af4845c212855070683.xml -> train_label_69.xml
# Filtered and updated XML: train_label_69.xml
# Renamed: 4_jpg.rf.5bfc23cc3b5df5457984f853e1f67048.jpg -> train_image_70.jpg
# Renamed: 4_jpg.rf.5bfc23cc3b5df5457984f853e1f67048.xml -> train_label_70.xml
# Filtered and updated XML: train_label_70.xml
# Renamed: 54_jpg.rf.bd70aded3b425a6ec56c708974e1b64e.jpg -> train_image_71.jpg
# Renamed: 54_jpg.rf.bd70aded3b425a6ec56c708974e1b64e.xml -> train_label_71.xml
# Filtered and updated XML: train_label_71.xml
# Renamed: 55_jpg.rf.8e952a5450cf77705a50a8bb95de1afc.jpg -> train_image_72.jpg
# Renamed: 55_jpg.rf.8e952a5450cf77705a50a8bb95de1afc.xml -> train_label_72.xml
# Filtered and updated XML: train_label_72.xml
# Renamed: 56_jpg.rf.40035bf709e41c1e1f8971b762e1793e.jpg -> train_image_73.jpg
# Renamed: 56_jpg.rf.40035bf709e41c1e1f8971b762e1793e.xml -> train_label_73.xml
# Filtered and updated XML: train_label_73.xml
# Renamed: 57_jpg.rf.d3e9a36597f2941a449d4e0bc4e5b4a3.jpg -> train_image_74.jpg
# Renamed: 57_jpg.rf.d3e9a36597f2941a449d4e0bc4e5b4a3.xml -> train_label_74.xml
# Filtered and updated XML: train_label_74.xml
# Renamed: 5_jpeg.rf.3e0b6931ecf852fc0525c84aa75cfd89.jpg -> train_image_75.jpg
# Renamed: 5_jpeg.rf.3e0b6931ecf852fc0525c84aa75cfd89.xml -> train_label_75.xml
# Filtered and updated XML: train_label_75.xml
# Renamed: 5_jpg.rf.8fbc18641a02b9e7aa608b423ddc8eed.jpg -> train_image_76.jpg
# Renamed: 5_jpg.rf.8fbc18641a02b9e7aa608b423ddc8eed.xml -> train_label_76.xml
# Filtered and updated XML: train_label_76.xml
# Renamed: 60_jpg.rf.209ec09319e9acc24d6d0017369db7ea.jpg -> train_image_77.jpg
# Renamed: 60_jpg.rf.209ec09319e9acc24d6d0017369db7ea.xml -> train_label_77.xml
# Filtered and updated XML: train_label_77.xml
# Renamed: 62_jpg.rf.069d025c9ec94c78fd0fb64f127c2012.jpg -> train_image_78.jpg
# Renamed: 62_jpg.rf.069d025c9ec94c78fd0fb64f127c2012.xml -> train_label_78.xml
# Filtered and updated XML: train_label_78.xml
# Renamed: 64_jpg.rf.35780ea2d8a765fb3bf070817555ff00.jpg -> train_image_79.jpg
# Renamed: 64_jpg.rf.35780ea2d8a765fb3bf070817555ff00.xml -> train_label_79.xml
# Filtered and updated XML: train_label_79.xml
# Renamed: 65_jpg.rf.4a5db4c1f9a7e22710e65c5fd5766ff0.jpg -> train_image_80.jpg
# Renamed: 65_jpg.rf.4a5db4c1f9a7e22710e65c5fd5766ff0.xml -> train_label_80.xml
# Filtered and updated XML: train_label_80.xml
# Renamed: 66_jpg.rf.f30ec02d14256c7a27a4d2bfecea64c2.jpg -> train_image_81.jpg
# Renamed: 66_jpg.rf.f30ec02d14256c7a27a4d2bfecea64c2.xml -> train_label_81.xml
# Filtered and updated XML: train_label_81.xml
# Renamed: 68_jpg.rf.f1f9d95aa2f961f487c4f26aa77b8aeb.jpg -> train_image_82.jpg
# Renamed: 68_jpg.rf.f1f9d95aa2f961f487c4f26aa77b8aeb.xml -> train_label_82.xml
# Filtered and updated XML: train_label_82.xml
# Renamed: 6_jpg.rf.241c24a0102e1b231aabca9c56fc7841.jpg -> train_image_83.jpg
# Renamed: 6_jpg.rf.241c24a0102e1b231aabca9c56fc7841.xml -> train_label_83.xml
# Filtered and updated XML: train_label_83.xml
# Renamed: 70_jpg.rf.8ae43aa8c1ed2ab5b100d2e6195bb9ef.jpg -> train_image_84.jpg
# Renamed: 70_jpg.rf.8ae43aa8c1ed2ab5b100d2e6195bb9ef.xml -> train_label_84.xml
# Filtered and updated XML: train_label_84.xml
# Renamed: 72_jpg.rf.4d34b9b6fe87b5891b596659f4914d9c.jpg -> train_image_85.jpg
# Renamed: 72_jpg.rf.4d34b9b6fe87b5891b596659f4914d9c.xml -> train_label_85.xml
# Filtered and updated XML: train_label_85.xml
# Renamed: 73_jpg.rf.19a15f4d7829e022e891a7d2b0d8839a.jpg -> train_image_86.jpg
# Renamed: 73_jpg.rf.19a15f4d7829e022e891a7d2b0d8839a.xml -> train_label_86.xml
# Filtered and updated XML: train_label_86.xml
# Renamed: 76_jpg.rf.da6763d7a5886580d55f49da1c3644a5.jpg -> train_image_87.jpg
# Renamed: 76_jpg.rf.da6763d7a5886580d55f49da1c3644a5.xml -> train_label_87.xml
# Filtered and updated XML: train_label_87.xml
# Renamed: 77_jpg.rf.eed421d6f579218cc60b8914a78bb754.jpg -> train_image_88.jpg
# Renamed: 77_jpg.rf.eed421d6f579218cc60b8914a78bb754.xml -> train_label_88.xml
# Filtered and updated XML: train_label_88.xml
# Renamed: 79_jpg.rf.8f8732383177a5bd98ac3cc78991f209.jpg -> train_image_89.jpg
# Renamed: 79_jpg.rf.8f8732383177a5bd98ac3cc78991f209.xml -> train_label_89.xml
# Filtered and updated XML: train_label_89.xml
# Renamed: 7_jpg.rf.7d0c0d8de887f4115b5517896a5a7897.jpg -> train_image_90.jpg
# Renamed: 7_jpg.rf.7d0c0d8de887f4115b5517896a5a7897.xml -> train_label_90.xml
# Filtered and updated XML: train_label_90.xml
# Renamed: 7_jpg.rf.d9a0fae280b2603765a15a8b73e00c36.jpg -> train_image_91.jpg
# Renamed: 7_jpg.rf.d9a0fae280b2603765a15a8b73e00c36.xml -> train_label_91.xml
# Filtered and updated XML: train_label_91.xml
# Renamed: 81_jpg.rf.8d0a7c208bb24e9094b66eb7b9b86a31.jpg -> train_image_92.jpg
# Renamed: 81_jpg.rf.8d0a7c208bb24e9094b66eb7b9b86a31.xml -> train_label_92.xml
# Filtered and updated XML: train_label_92.xml
# Renamed: 84_jpg.rf.b42f4819fa9db713cd37cc75eaacba8b.jpg -> train_image_93.jpg
# Renamed: 84_jpg.rf.b42f4819fa9db713cd37cc75eaacba8b.xml -> train_label_93.xml
# Filtered and updated XML: train_label_93.xml
# Renamed: 85_jpg.rf.08b6f43b6b039a36bf63fc8866b32a4b.jpg -> train_image_94.jpg
# Renamed: 85_jpg.rf.08b6f43b6b039a36bf63fc8866b32a4b.xml -> train_label_94.xml
# Filtered and updated XML: train_label_94.xml
# Renamed: 86_jpg.rf.e33673aefc718d907dd99ed415f8ce85.jpg -> train_image_95.jpg
# Renamed: 86_jpg.rf.e33673aefc718d907dd99ed415f8ce85.xml -> train_label_95.xml
# Filtered and updated XML: train_label_95.xml
# Renamed: 88_jpg.rf.3f0feb05af08bed2aad07935897a0d4f.jpg -> train_image_96.jpg
# Renamed: 88_jpg.rf.3f0feb05af08bed2aad07935897a0d4f.xml -> train_label_96.xml
# Filtered and updated XML: train_label_96.xml
# Renamed: 89_jpg.rf.bef84155c2796f19e98fc3ed0282b3e3.jpg -> train_image_97.jpg
# Renamed: 89_jpg.rf.bef84155c2796f19e98fc3ed0282b3e3.xml -> train_label_97.xml
# Filtered and updated XML: train_label_97.xml
# Renamed: 8_jpg.rf.3cfba8363808a0e1451ad88265209079.jpg -> train_image_98.jpg
# Renamed: 8_jpg.rf.3cfba8363808a0e1451ad88265209079.xml -> train_label_98.xml
# Filtered and updated XML: train_label_98.xml
# Renamed: 90_jpg.rf.0e16de3bcc688660594a8a3b97e2a56b.jpg -> train_image_99.jpg
# Renamed: 90_jpg.rf.0e16de3bcc688660594a8a3b97e2a56b.xml -> train_label_99.xml
# Filtered and updated XML: train_label_99.xml
# Renamed: 92_jpg.rf.542633036cc125a06aaa08a2694d173e.jpg -> train_image_100.jpg
# Renamed: 92_jpg.rf.542633036cc125a06aaa08a2694d173e.xml -> train_label_100.xml
# Filtered and updated XML: train_label_100.xml
# Renamed: 93_jpg.rf.8ee65573034bae0765e9e42d0bc7b75a.jpg -> train_image_101.jpg
# Renamed: 93_jpg.rf.8ee65573034bae0765e9e42d0bc7b75a.xml -> train_label_101.xml
# Filtered and updated XML: train_label_101.xml
# Renamed: 94_jpg.rf.1a37f4dffcd7851b29203d684e9a2bce.jpg -> train_image_102.jpg
# Renamed: 94_jpg.rf.1a37f4dffcd7851b29203d684e9a2bce.xml -> train_label_102.xml
# Filtered and updated XML: train_label_102.xml
# Renamed: 95_jpg.rf.21508c87957f64e7e0f787755f97011f.jpg -> train_image_103.jpg
# Renamed: 95_jpg.rf.21508c87957f64e7e0f787755f97011f.xml -> train_label_103.xml
# Filtered and updated XML: train_label_103.xml
# Renamed: 96_jpg.rf.8f8e3fdccc4d2e781930ddd100e48585.jpg -> train_image_104.jpg
# Renamed: 96_jpg.rf.8f8e3fdccc4d2e781930ddd100e48585.xml -> train_label_104.xml
# Filtered and updated XML: train_label_104.xml
# Renamed: 99_jpg.rf.704e354c56467bc3944633601fe0ea6a.jpg -> train_image_105.jpg
# Renamed: 99_jpg.rf.704e354c56467bc3944633601fe0ea6a.xml -> train_label_105.xml
# Filtered and updated XML: train_label_105.xml
# Renamed: IMG-20230809-WA0006_jpg.rf.72dc91a1e02bfca7d157b8631ee61fe8.jpg -> train_image_106.jpg
# Renamed: IMG-20230809-WA0006_jpg.rf.72dc91a1e02bfca7d157b8631ee61fe8.xml -> train_label_106.xml
# Filtered and updated XML: train_label_106.xml
# Renamed: IMG_20201217_133251_copy_359x342_jpg.rf.fd0142b219a3315b5c56672f2aa1e84b.jpg -> train_image_107.jpg
# Renamed: IMG_20201217_133251_copy_359x342_jpg.rf.fd0142b219a3315b5c56672f2aa1e84b.xml -> train_label_107.xml
# Filtered and updated XML: train_label_107.xml
# Renamed: IMG_20220501_220541_jpg.rf.c9d62bf1c196b2faf9c380d2d4bfacb2.jpg -> train_image_108.jpg
# Renamed: IMG_20220501_220541_jpg.rf.c9d62bf1c196b2faf9c380d2d4bfacb2.xml -> train_label_108.xml
# Filtered and updated XML: train_label_108.xml
# Renamed: X00016469612_jpg.rf.d6bec0f1669fb44830856eddafb14c56.jpg -> train_image_109.jpg
# Renamed: X00016469612_jpg.rf.d6bec0f1669fb44830856eddafb14c56.xml -> train_label_109.xml
# Filtered and updated XML: train_label_109.xml
# Renamed: X00016469619_jpg.rf.0c58396358d826bab025d078d62ff6a5.jpg -> train_image_110.jpg
# Renamed: X00016469619_jpg.rf.0c58396358d826bab025d078d62ff6a5.xml -> train_label_110.xml
# Filtered and updated XML: train_label_110.xml
# Renamed: X00016469620_jpg.rf.f7778534fe76bd84ccbf11c33daf723f.jpg -> train_image_111.jpg
# Renamed: X00016469620_jpg.rf.f7778534fe76bd84ccbf11c33daf723f.xml -> train_label_111.xml
# Filtered and updated XML: train_label_111.xml
# Renamed: X00016469622_jpg.rf.420d1df86977753f472be10cbf395cd0.jpg -> train_image_112.jpg
# Renamed: X00016469622_jpg.rf.420d1df86977753f472be10cbf395cd0.xml -> train_label_112.xml
# Filtered and updated XML: train_label_112.xml
# Renamed: X00016469669_jpg.rf.06e32f0673e9bd576285d1095f93993d.jpg -> train_image_113.jpg
# Renamed: X00016469669_jpg.rf.06e32f0673e9bd576285d1095f93993d.xml -> train_label_113.xml
# Filtered and updated XML: train_label_113.xml
# Renamed: X00016469676_jpg.rf.18c15898be43d96ff5652850b7da7164.jpg -> train_image_114.jpg
# Renamed: X00016469676_jpg.rf.18c15898be43d96ff5652850b7da7164.xml -> train_label_114.xml
# Filtered and updated XML: train_label_114.xml
# Renamed: X51005200938_jpg.rf.5dd39a89539f59edfe76d74dac543cd0.jpg -> train_image_115.jpg
# Renamed: X51005200938_jpg.rf.5dd39a89539f59edfe76d74dac543cd0.xml -> train_label_115.xml
# Filtered and updated XML: train_label_115.xml
# Renamed: X51005230617_jpg.rf.3287395175b6e8d72a70e21d1bd53f31.jpg -> train_image_116.jpg
# Renamed: X51005230617_jpg.rf.3287395175b6e8d72a70e21d1bd53f31.xml -> train_label_116.xml
# Filtered and updated XML: train_label_116.xml
# Renamed: X51005255805_jpg.rf.71fbb2e9167d8e2dddb876a84e3a493b.jpg -> train_image_117.jpg
# Renamed: X51005255805_jpg.rf.71fbb2e9167d8e2dddb876a84e3a493b.xml -> train_label_117.xml
# Filtered and updated XML: train_label_117.xml
# Renamed: X51005268200_jpg.rf.3b2fc8a717b05c778fa2822ba3c4cb2c.jpg -> train_image_118.jpg
# Renamed: X51005268200_jpg.rf.3b2fc8a717b05c778fa2822ba3c4cb2c.xml -> train_label_118.xml
# Filtered and updated XML: train_label_118.xml
# Renamed: X51005268262_jpg.rf.289e3dfc34e1ef97f298bd70707f60e0.jpg -> train_image_119.jpg
# Renamed: X51005268262_jpg.rf.289e3dfc34e1ef97f298bd70707f60e0.xml -> train_label_119.xml
# Filtered and updated XML: train_label_119.xml
# Renamed: X51005268400_jpg.rf.b16a0fba55bcda99ecd9489b8b8708ce.jpg -> train_image_120.jpg
# Renamed: X51005268400_jpg.rf.b16a0fba55bcda99ecd9489b8b8708ce.xml -> train_label_120.xml
# Filtered and updated XML: train_label_120.xml
# Renamed: X51005301667-1-_jpg.rf.e08ad7f4e2b3aa16b7569939c83b4163.jpg -> train_image_121.jpg
# Renamed: X51005301667-1-_jpg.rf.e08ad7f4e2b3aa16b7569939c83b4163.xml -> train_label_121.xml
# Filtered and updated XML: train_label_121.xml
# Renamed: X51005306399-1-_jpg.rf.6bad36603eec9814c82062a2434eaa96.jpg -> train_image_122.jpg
# Renamed: X51005306399-1-_jpg.rf.6bad36603eec9814c82062a2434eaa96.xml -> train_label_122.xml
# Filtered and updated XML: train_label_122.xml
# Renamed: X51005361895-1-_jpg.rf.4a298967b31b3e8255caedef6239372b.jpg -> train_image_123.jpg
# Renamed: X51005361895-1-_jpg.rf.4a298967b31b3e8255caedef6239372b.xml -> train_label_123.xml
# Filtered and updated XML: train_label_123.xml
# Renamed: X51005361897-1-_jpg.rf.e9481daa37061a0461bc5ce5e34b3f0b.jpg -> train_image_124.jpg
# Renamed: X51005361897-1-_jpg.rf.e9481daa37061a0461bc5ce5e34b3f0b.xml -> train_label_124.xml
# Filtered and updated XML: train_label_124.xml
# Renamed: X51005361898-1-_jpg.rf.ee09fa036cae5c1679243fb1b7a934ec.jpg -> train_image_125.jpg
# Renamed: X51005361898-1-_jpg.rf.ee09fa036cae5c1679243fb1b7a934ec.xml -> train_label_125.xml
# Filtered and updated XML: train_label_125.xml
# Renamed: X51005361900-1-_jpg.rf.4c7c0d43a459848916201cafc7555690.jpg -> train_image_126.jpg
# Renamed: X51005361900-1-_jpg.rf.4c7c0d43a459848916201cafc7555690.xml -> train_label_126.xml
# Filtered and updated XML: train_label_126.xml
# Renamed: X51005361907_jpg.rf.68b75aa2f47dbf788265bca903c61156.jpg -> train_image_127.jpg
# Renamed: X51005361907_jpg.rf.68b75aa2f47dbf788265bca903c61156.xml -> train_label_127.xml
# Filtered and updated XML: train_label_127.xml
# Renamed: X51005361950_jpg.rf.5cd9b76e66b5823ed2d98d671dcceb31.jpg -> train_image_128.jpg
# Renamed: X51005361950_jpg.rf.5cd9b76e66b5823ed2d98d671dcceb31.xml -> train_label_128.xml
# Filtered and updated XML: train_label_128.xml
# Renamed: X51005365179_jpg.rf.71da2beeb4cdede9438a219847190fe0.jpg -> train_image_129.jpg
# Renamed: X51005365179_jpg.rf.71da2beeb4cdede9438a219847190fe0.xml -> train_label_129.xml
# Filtered and updated XML: train_label_129.xml
# Renamed: X51005433492-1-_jpg.rf.49c15cd1a87769b845215f270cd3f919.jpg -> train_image_130.jpg
# Renamed: X51005433492-1-_jpg.rf.49c15cd1a87769b845215f270cd3f919.xml -> train_label_130.xml
# Filtered and updated XML: train_label_130.xml
# Renamed: X51005433494_jpg.rf.6aef162cb5eef0f9a7c9de274ab8bc64.jpg -> train_image_131.jpg
# Renamed: X51005433494_jpg.rf.6aef162cb5eef0f9a7c9de274ab8bc64.xml -> train_label_131.xml
# Filtered and updated XML: train_label_131.xml
# Renamed: X51005433514_jpg.rf.dc05062948d64feaae59201587c3891e.jpg -> train_image_132.jpg
# Renamed: X51005433514_jpg.rf.dc05062948d64feaae59201587c3891e.xml -> train_label_132.xml
# Filtered and updated XML: train_label_132.xml
# Renamed: X51005433522_jpg.rf.735b7525763c52c794f32f9779578a1a.jpg -> train_image_133.jpg
# Renamed: X51005433522_jpg.rf.735b7525763c52c794f32f9779578a1a.xml -> train_label_133.xml
# Filtered and updated XML: train_label_133.xml
# Renamed: X51005433533_jpg.rf.5a14cfc306baf7ef4c0231369f7a8fda.jpg -> train_image_134.jpg
# Renamed: X51005433533_jpg.rf.5a14cfc306baf7ef4c0231369f7a8fda.xml -> train_label_134.xml
# Filtered and updated XML: train_label_134.xml
# Renamed: X51005433538_jpg.rf.72ef80b112f9f588d0e3d3d9725881ef.jpg -> train_image_135.jpg
# Renamed: X51005433538_jpg.rf.72ef80b112f9f588d0e3d3d9725881ef.xml -> train_label_135.xml
# Filtered and updated XML: train_label_135.xml
# Renamed: X51005433541_jpg.rf.b8c979ae220cace7046ff98ed85ddeb8.jpg -> train_image_136.jpg
# Renamed: X51005433541_jpg.rf.b8c979ae220cace7046ff98ed85ddeb8.xml -> train_label_136.xml
# Filtered and updated XML: train_label_136.xml
# Renamed: X51005433552_jpg.rf.795dd34db152a78519e7c343af8d50cd.jpg -> train_image_137.jpg
# Renamed: X51005433552_jpg.rf.795dd34db152a78519e7c343af8d50cd.xml -> train_label_137.xml
# Filtered and updated XML: train_label_137.xml
# Renamed: X51005433553_jpg.rf.d7de738a86f82fa3f6791bd244588b5b.jpg -> train_image_138.jpg
# Renamed: X51005433553_jpg.rf.d7de738a86f82fa3f6791bd244588b5b.xml -> train_label_138.xml
# Filtered and updated XML: train_label_138.xml
# Renamed: X51005441398_jpg.rf.cb84bcd74a49b3684d7712801afe1cdf.jpg -> train_image_139.jpg
# Renamed: X51005441398_jpg.rf.cb84bcd74a49b3684d7712801afe1cdf.xml -> train_label_139.xml
# Filtered and updated XML: train_label_139.xml
# Renamed: X51005441402_jpg.rf.e76d3dbcf270d0473480e5fef9ef34bb.jpg -> train_image_140.jpg
# Renamed: X51005441402_jpg.rf.e76d3dbcf270d0473480e5fef9ef34bb.xml -> train_label_140.xml
# Filtered and updated XML: train_label_140.xml
# Renamed: X51005441407_jpg.rf.ce30c022d32545b75625715a891eb0c6.jpg -> train_image_141.jpg
# Renamed: X51005441407_jpg.rf.ce30c022d32545b75625715a891eb0c6.xml -> train_label_141.xml
# Filtered and updated XML: train_label_141.xml
# Renamed: X51005441408_jpg.rf.94e17550fe0f67dd88b1a7df500ccbdf.jpg -> train_image_142.jpg
# Renamed: X51005441408_jpg.rf.94e17550fe0f67dd88b1a7df500ccbdf.xml -> train_label_142.xml
# Filtered and updated XML: train_label_142.xml
# Renamed: X51005442333_jpg.rf.52b0edc56c18e90a97e732f4370e522c.jpg -> train_image_143.jpg
# Renamed: X51005442333_jpg.rf.52b0edc56c18e90a97e732f4370e522c.xml -> train_label_143.xml
# Filtered and updated XML: train_label_143.xml
# Renamed: X51005442341_jpg.rf.3e58f3f7cc4118753103fec956297a87.jpg -> train_image_144.jpg
# Renamed: X51005442341_jpg.rf.3e58f3f7cc4118753103fec956297a87.xml -> train_label_144.xml
# Filtered and updated XML: train_label_144.xml
# Renamed: X51005442346_jpg.rf.0fbabc2c40a598d0de8c78b68b127154.jpg -> train_image_145.jpg
# Renamed: X51005442346_jpg.rf.0fbabc2c40a598d0de8c78b68b127154.xml -> train_label_145.xml
# Filtered and updated XML: train_label_145.xml
# Renamed: X51005442378_jpg.rf.c40e3d2e286a921ee7cb523e269943d5.jpg -> train_image_146.jpg
# Renamed: X51005442378_jpg.rf.c40e3d2e286a921ee7cb523e269943d5.xml -> train_label_146.xml
# Filtered and updated XML: train_label_146.xml
# Renamed: X51005442379_jpg.rf.018d62ebfb1309eaee1270bb4e1bae45.jpg -> train_image_147.jpg
# Renamed: X51005442379_jpg.rf.018d62ebfb1309eaee1270bb4e1bae45.xml -> train_label_147.xml
# Filtered and updated XML: train_label_147.xml
# Renamed: X51005442383_jpg.rf.a5841f7eb368e85e716fe0a275c2e6d1.jpg -> train_image_148.jpg
# Renamed: X51005442383_jpg.rf.a5841f7eb368e85e716fe0a275c2e6d1.xml -> train_label_148.xml
# Filtered and updated XML: train_label_148.xml
# Renamed: X51005442384_jpg.rf.f6f79b04769d5c1147347ba21c5de48e.jpg -> train_image_149.jpg
# Renamed: X51005442384_jpg.rf.f6f79b04769d5c1147347ba21c5de48e.xml -> train_label_149.xml
# Filtered and updated XML: train_label_149.xml
# Renamed: X51005442394_jpg.rf.7db46b339ff82a948c831f10c1d229e0.jpg -> train_image_150.jpg
# Renamed: X51005442394_jpg.rf.7db46b339ff82a948c831f10c1d229e0.xml -> train_label_150.xml
# Filtered and updated XML: train_label_150.xml
# Renamed: X51005442397_jpg.rf.4f8316d291d8bd4aa7aec5d0c442f8c8.jpg -> train_image_151.jpg
# Renamed: X51005442397_jpg.rf.4f8316d291d8bd4aa7aec5d0c442f8c8.xml -> train_label_151.xml
# Filtered and updated XML: train_label_151.xml
# Renamed: X51005444033_jpg.rf.14ae060d007a2e22baafdf13db81eadd.jpg -> train_image_152.jpg
# Renamed: X51005444033_jpg.rf.14ae060d007a2e22baafdf13db81eadd.xml -> train_label_152.xml
# Filtered and updated XML: train_label_152.xml
# Renamed: X51005444045_jpg.rf.d5f7603d518562591b817d2398c9702d.jpg -> train_image_153.jpg
# Renamed: X51005444045_jpg.rf.d5f7603d518562591b817d2398c9702d.xml -> train_label_153.xml
# Filtered and updated XML: train_label_153.xml
# Renamed: X51005447832_jpg.rf.d68caca3f0ed7833ff1ccb00ff5b037a.jpg -> train_image_154.jpg
# Renamed: X51005447832_jpg.rf.d68caca3f0ed7833ff1ccb00ff5b037a.xml -> train_label_154.xml
# Filtered and updated XML: train_label_154.xml
# Renamed: X51005447833_jpg.rf.591b03ebfb2163307620bfe4d63df662.jpg -> train_image_155.jpg
# Renamed: X51005447833_jpg.rf.591b03ebfb2163307620bfe4d63df662.xml -> train_label_155.xml
# Filtered and updated XML: train_label_155.xml
# Renamed: X51005447839_jpg.rf.d774c740a95763aa0e783ce1260cb579.jpg -> train_image_156.jpg
# Renamed: X51005447839_jpg.rf.d774c740a95763aa0e783ce1260cb579.xml -> train_label_156.xml
# Filtered and updated XML: train_label_156.xml
# Renamed: X51005447840_jpg.rf.1d04ed4b717d4a17845fee0ae6aacb25.jpg -> train_image_157.jpg
# Renamed: X51005447840_jpg.rf.1d04ed4b717d4a17845fee0ae6aacb25.xml -> train_label_157.xml
# Filtered and updated XML: train_label_157.xml
# Renamed: X51005447848_jpg.rf.6783b5ff6114808986dd8d4ba7e7ee70.jpg -> train_image_158.jpg
# Renamed: X51005447848_jpg.rf.6783b5ff6114808986dd8d4ba7e7ee70.xml -> train_label_158.xml
# Filtered and updated XML: train_label_158.xml
# Renamed: X51005447850_jpg.rf.bccaacaae3a64b7e564a80626f0f2b29.jpg -> train_image_159.jpg
# Renamed: X51005447850_jpg.rf.bccaacaae3a64b7e564a80626f0f2b29.xml -> train_label_159.xml
# Filtered and updated XML: train_label_159.xml
# Renamed: X51005447852_jpg.rf.4f8010ab4d8a866a5cc1b2f27c53a60c.jpg -> train_image_160.jpg
# Renamed: X51005447852_jpg.rf.4f8010ab4d8a866a5cc1b2f27c53a60c.xml -> train_label_160.xml
# Filtered and updated XML: train_label_160.xml
# Renamed: X51005447853_jpg.rf.ffc1330f5c2707c0d06616d0b99628d0.jpg -> train_image_161.jpg
# Renamed: X51005447853_jpg.rf.ffc1330f5c2707c0d06616d0b99628d0.xml -> train_label_161.xml
# Filtered and updated XML: train_label_161.xml
# Renamed: X51005447860-1-_jpg.rf.2dc30b66dff54196d442ac822dfe7c48.jpg -> train_image_162.jpg
# Renamed: X51005447860-1-_jpg.rf.2dc30b66dff54196d442ac822dfe7c48.xml -> train_label_162.xml
# Filtered and updated XML: train_label_162.xml
# Renamed: X51005447861-1-_jpg.rf.f71e0ff2e1baaffe6b806e6d55b2da8a.jpg -> train_image_163.jpg
# Renamed: X51005447861-1-_jpg.rf.f71e0ff2e1baaffe6b806e6d55b2da8a.xml -> train_label_163.xml
# Filtered and updated XML: train_label_163.xml
# Renamed: X51005453729-1-_jpg.rf.32b6632042f14400db3fce7cbe57497a.jpg -> train_image_164.jpg
# Renamed: X51005453729-1-_jpg.rf.32b6632042f14400db3fce7cbe57497a.xml -> train_label_164.xml
# Filtered and updated XML: train_label_164.xml
# Renamed: X51005453801-1-_jpg.rf.515bf045b1c237cbf18d753a497e646d.jpg -> train_image_165.jpg
# Renamed: X51005453801-1-_jpg.rf.515bf045b1c237cbf18d753a497e646d.xml -> train_label_165.xml
# Filtered and updated XML: train_label_165.xml
# Renamed: X51005453804_jpg.rf.5963a22cfc6428627c4ae8071c422099.jpg -> train_image_166.jpg
# Renamed: X51005453804_jpg.rf.5963a22cfc6428627c4ae8071c422099.xml -> train_label_166.xml
# Filtered and updated XML: train_label_166.xml
# Renamed: X51005568827_jpg.rf.e0d3eda3c1a3c0e531707e2e03692b02.jpg -> train_image_167.jpg
# Renamed: X51005568827_jpg.rf.e0d3eda3c1a3c0e531707e2e03692b02.xml -> train_label_167.xml
# Filtered and updated XML: train_label_167.xml
# Renamed: X51005568829_jpg.rf.8a835bf8e124f9ded0d40aa9f6ac633d.jpg -> train_image_168.jpg
# Renamed: X51005568829_jpg.rf.8a835bf8e124f9ded0d40aa9f6ac633d.xml -> train_label_168.xml
# Filtered and updated XML: train_label_168.xml
# Renamed: X51005568880_jpg.rf.ef9a647ba8afeb49519029049306fe45.jpg -> train_image_169.jpg
# Renamed: X51005568880_jpg.rf.ef9a647ba8afeb49519029049306fe45.xml -> train_label_169.xml
# Filtered and updated XML: train_label_169.xml
# Renamed: X51005568881_jpg.rf.1c11b2fe572abbf0cbcdb6c536ddcc2d.jpg -> train_image_170.jpg
# Renamed: X51005568881_jpg.rf.1c11b2fe572abbf0cbcdb6c536ddcc2d.xml -> train_label_170.xml
# Filtered and updated XML: train_label_170.xml
# Renamed: X51005568884_jpg.rf.96ad11aeaa13649fd3f4e651c19f782a.jpg -> train_image_171.jpg
# Renamed: X51005568884_jpg.rf.96ad11aeaa13649fd3f4e651c19f782a.xml -> train_label_171.xml
# Filtered and updated XML: train_label_171.xml
# Renamed: X51005568891_jpg.rf.e175584d8fd5199b70512c8435e72e81.jpg -> train_image_172.jpg
# Renamed: X51005568891_jpg.rf.e175584d8fd5199b70512c8435e72e81.xml -> train_label_172.xml
# Filtered and updated XML: train_label_172.xml
# Renamed: X51005568900_jpg.rf.9c58f64e462db64066ab84e41d344616.jpg -> train_image_173.jpg
# Renamed: X51005568900_jpg.rf.9c58f64e462db64066ab84e41d344616.xml -> train_label_173.xml
# Filtered and updated XML: train_label_173.xml
# Renamed: X51005568911_jpg.rf.9c716ab7142d8e0e24e0469a54372ff8.jpg -> train_image_174.jpg
# Renamed: X51005568911_jpg.rf.9c716ab7142d8e0e24e0469a54372ff8.xml -> train_label_174.xml
# Filtered and updated XML: train_label_174.xml
# Renamed: X51005568913_jpg.rf.4176ed92dd546553955e4d7c20e14fba.jpg -> train_image_175.jpg
# Renamed: X51005568913_jpg.rf.4176ed92dd546553955e4d7c20e14fba.xml -> train_label_175.xml
# Filtered and updated XML: train_label_175.xml
# Renamed: X51005577192_jpg.rf.1320802671333d95d9533ef2e34b5660.jpg -> train_image_176.jpg
# Renamed: X51005577192_jpg.rf.1320802671333d95d9533ef2e34b5660.xml -> train_label_176.xml
# Filtered and updated XML: train_label_176.xml
# Renamed: X51005587254_jpg.rf.9f8d082f2847ccba3a4a2df5a3ba9718.jpg -> train_image_177.jpg
# Renamed: X51005587254_jpg.rf.9f8d082f2847ccba3a4a2df5a3ba9718.xml -> train_label_177.xml
# Filtered and updated XML: train_label_177.xml
# Renamed: X51005587267-1-_jpg.rf.f34fa28adc9cb657701685e9749d242e.jpg -> train_image_178.jpg
# Renamed: X51005587267-1-_jpg.rf.f34fa28adc9cb657701685e9749d242e.xml -> train_label_178.xml
# Filtered and updated XML: train_label_178.xml
# Renamed: X51005605284-1-_jpg.rf.c0c06d4fec45821ee8944c10ab357802.jpg -> train_image_179.jpg
# Renamed: X51005605284-1-_jpg.rf.c0c06d4fec45821ee8944c10ab357802.xml -> train_label_179.xml
# Filtered and updated XML: train_label_179.xml
# Renamed: X51005605286-1-_jpg.rf.1efd7a742dbf05cbc58f67ecc958ec12.jpg -> train_image_180.jpg
# Renamed: X51005605286-1-_jpg.rf.1efd7a742dbf05cbc58f67ecc958ec12.xml -> train_label_180.xml
# Filtered and updated XML: train_label_180.xml
# Renamed: X51005605334_jpg.rf.dbb8241649e67bcf332fabcb4a721004.jpg -> train_image_181.jpg
# Renamed: X51005605334_jpg.rf.dbb8241649e67bcf332fabcb4a721004.xml -> train_label_181.xml
# Filtered and updated XML: train_label_181.xml
# Renamed: X51005605335_jpg.rf.2806dc4d557b29390adc5d8ee21857d1.jpg -> train_image_182.jpg
# Renamed: X51005605335_jpg.rf.2806dc4d557b29390adc5d8ee21857d1.xml -> train_label_182.xml
# Filtered and updated XML: train_label_182.xml
# Renamed: X51005663272_jpg.rf.5740a8fd6e97caf34f77250b83c1653f.jpg -> train_image_183.jpg
# Renamed: X51005663272_jpg.rf.5740a8fd6e97caf34f77250b83c1653f.xml -> train_label_183.xml
# Filtered and updated XML: train_label_183.xml
# Renamed: X51005663273_jpg.rf.ba671e73b20904387305f91c2b320491.jpg -> train_image_184.jpg
# Renamed: X51005663273_jpg.rf.ba671e73b20904387305f91c2b320491.xml -> train_label_184.xml
# Filtered and updated XML: train_label_184.xml
# Renamed: X51005663276_jpg.rf.002b7a61701971ba7b1f974b5b56cb51.jpg -> train_image_185.jpg
# Renamed: X51005663276_jpg.rf.002b7a61701971ba7b1f974b5b56cb51.xml -> train_label_185.xml
# Filtered and updated XML: train_label_185.xml
# Renamed: X51005663278_jpg.rf.40ca5b595accebbfb2d3afcaca70eb92.jpg -> train_image_186.jpg
# Renamed: X51005663278_jpg.rf.40ca5b595accebbfb2d3afcaca70eb92.xml -> train_label_186.xml
# Filtered and updated XML: train_label_186.xml
# Renamed: X51005663279-1-_jpg.rf.6ba9d3ebc4d5b58c227f407d61ec969e.jpg -> train_image_187.jpg
# Renamed: X51005663279-1-_jpg.rf.6ba9d3ebc4d5b58c227f407d61ec969e.xml -> train_label_187.xml
# Filtered and updated XML: train_label_187.xml
# Renamed: X51005663280-1-_jpg.rf.cbf40d2d25935c77c5e8a3477219df00.jpg -> train_image_188.jpg
# Renamed: X51005663280-1-_jpg.rf.cbf40d2d25935c77c5e8a3477219df00.xml -> train_label_188.xml
# Filtered and updated XML: train_label_188.xml
# Renamed: X51005663297_jpg.rf.7850ebf5ca2263b94e5f06e778b55926.jpg -> train_image_189.jpg
# Renamed: X51005663297_jpg.rf.7850ebf5ca2263b94e5f06e778b55926.xml -> train_label_189.xml
# Filtered and updated XML: train_label_189.xml
# Renamed: X51005663298_jpg.rf.a836f333f889c6ae2ee3762f4535a6a1.jpg -> train_image_190.jpg
# Renamed: X51005663298_jpg.rf.a836f333f889c6ae2ee3762f4535a6a1.xml -> train_label_190.xml
# Filtered and updated XML: train_label_190.xml
# Renamed: X51005663301_jpg.rf.8f0aa805bd1f1977d3bcf7312a85c9d3.jpg -> train_image_191.jpg
# Renamed: X51005663301_jpg.rf.8f0aa805bd1f1977d3bcf7312a85c9d3.xml -> train_label_191.xml
# Filtered and updated XML: train_label_191.xml
# Renamed: X51005663311_jpg.rf.10a8275b6b602bcc0ecde144281b9100.jpg -> train_image_192.jpg
# Renamed: X51005663311_jpg.rf.10a8275b6b602bcc0ecde144281b9100.xml -> train_label_192.xml
# Filtered and updated XML: train_label_192.xml
# Renamed: X51005663317_jpg.rf.b78a4a3c874692ef6eb2235d5b2ebf24.jpg -> train_image_193.jpg
# Renamed: X51005663317_jpg.rf.b78a4a3c874692ef6eb2235d5b2ebf24.xml -> train_label_193.xml
# Filtered and updated XML: train_label_193.xml
# Renamed: X51005663324_jpg.rf.2e442983c40853d61dedc34f5dfda079.jpg -> train_image_194.jpg
# Renamed: X51005663324_jpg.rf.2e442983c40853d61dedc34f5dfda079.xml -> train_label_194.xml
# Filtered and updated XML: train_label_194.xml
# Renamed: X51005675095_jpg.rf.ef3e4ee13220fc88cec4d1a067d43049.jpg -> train_image_195.jpg
# Renamed: X51005675095_jpg.rf.ef3e4ee13220fc88cec4d1a067d43049.xml -> train_label_195.xml
# Filtered and updated XML: train_label_195.xml
# Renamed: X51005676536_jpg.rf.aef815cc31cb8055daba09f84b5f5679.jpg -> train_image_196.jpg
# Renamed: X51005676536_jpg.rf.aef815cc31cb8055daba09f84b5f5679.xml -> train_label_196.xml
# Filtered and updated XML: train_label_196.xml
# Renamed: X51005676538_jpg.rf.47011d7d7e289b4b9888268c59e058d1.jpg -> train_image_197.jpg
# Renamed: X51005676538_jpg.rf.47011d7d7e289b4b9888268c59e058d1.xml -> train_label_197.xml
# Filtered and updated XML: train_label_197.xml
# Renamed: X51005676539_jpg.rf.69b4c7c9759983681460a8b15ff94614.jpg -> train_image_198.jpg
# Renamed: X51005676539_jpg.rf.69b4c7c9759983681460a8b15ff94614.xml -> train_label_198.xml
# Filtered and updated XML: train_label_198.xml
# Renamed: X51005676540-1-_jpg.rf.c9efa2230ba81091ded50ea5338a4dea.jpg -> train_image_199.jpg
# Renamed: X51005676540-1-_jpg.rf.c9efa2230ba81091ded50ea5338a4dea.xml -> train_label_199.xml
# Filtered and updated XML: train_label_199.xml
# Renamed: X51005676541-1-_jpg.rf.21d102c8fbf1e028bb8e2fefd2c253cf.jpg -> train_image_200.jpg
# Renamed: X51005676541-1-_jpg.rf.21d102c8fbf1e028bb8e2fefd2c253cf.xml -> train_label_200.xml
# Filtered and updated XML: train_label_200.xml
# Renamed: X51005676543-1-_jpg.rf.1fe4504d1739fbaba4d8bd462bb52ffb.jpg -> train_image_201.jpg
# Renamed: X51005676543-1-_jpg.rf.1fe4504d1739fbaba4d8bd462bb52ffb.xml -> train_label_201.xml
# Filtered and updated XML: train_label_201.xml
# Renamed: X51005676544_jpg.rf.ab40f736aafd2c3e24c775c491fadb87.jpg -> train_image_202.jpg
# Renamed: X51005676544_jpg.rf.ab40f736aafd2c3e24c775c491fadb87.xml -> train_label_202.xml
# Filtered and updated XML: train_label_202.xml
# Renamed: X51005676545_jpg.rf.8c6cc0ca222d02ac572eb2ac1ef3204a.jpg -> train_image_203.jpg
# Renamed: X51005676545_jpg.rf.8c6cc0ca222d02ac572eb2ac1ef3204a.xml -> train_label_203.xml
# Filtered and updated XML: train_label_203.xml
# Renamed: X51005676547-1-_jpg.rf.49a392c6ea93d4d0c20ffc7cb1a8aeae.jpg -> train_image_204.jpg
# Renamed: X51005676547-1-_jpg.rf.49a392c6ea93d4d0c20ffc7cb1a8aeae.xml -> train_label_204.xml
# Filtered and updated XML: train_label_204.xml
# Renamed: X51005676549-1-_jpg.rf.07f9b9337710d63f51db7a1adb0ac5ce.jpg -> train_image_205.jpg
# Renamed: X51005676549-1-_jpg.rf.07f9b9337710d63f51db7a1adb0ac5ce.xml -> train_label_205.xml
# Filtered and updated XML: train_label_205.xml
# Renamed: X51005677328-1-_jpg.rf.5cd00ce7e8372b1bba96590210942ba2.jpg -> train_image_206.jpg
# Renamed: X51005677328-1-_jpg.rf.5cd00ce7e8372b1bba96590210942ba2.xml -> train_label_206.xml
# Filtered and updated XML: train_label_206.xml
# Renamed: X51005677332_jpg.rf.af898e380dd1cbb8510243df70687241.jpg -> train_image_207.jpg
# Renamed: X51005677332_jpg.rf.af898e380dd1cbb8510243df70687241.xml -> train_label_207.xml
# Filtered and updated XML: train_label_207.xml
# Renamed: X51005677335_jpg.rf.96dfd4d80a42cc9a8248ef0d7ac3d6ae.jpg -> train_image_208.jpg
# Renamed: X51005677335_jpg.rf.96dfd4d80a42cc9a8248ef0d7ac3d6ae.xml -> train_label_208.xml
# Filtered and updated XML: train_label_208.xml
# Renamed: X51005677339_jpg.rf.cdfed1258427db6d89b6c6aefefe3f60.jpg -> train_image_209.jpg
# Renamed: X51005677339_jpg.rf.cdfed1258427db6d89b6c6aefefe3f60.xml -> train_label_209.xml
# Filtered and updated XML: train_label_209.xml
# Renamed: X51005685355-1-_jpg.rf.eaf018d0386ab514ec86b195aeafaf0f.jpg -> train_image_210.jpg
# Renamed: X51005685355-1-_jpg.rf.eaf018d0386ab514ec86b195aeafaf0f.xml -> train_label_210.xml
# Filtered and updated XML: train_label_210.xml
# Renamed: X51005705722_jpg.rf.135871c58220fcd467e1c5238ccebef8.jpg -> train_image_211.jpg
# Renamed: X51005705722_jpg.rf.135871c58220fcd467e1c5238ccebef8.xml -> train_label_211.xml
# Filtered and updated XML: train_label_211.xml
# Renamed: X51005705760_jpg.rf.90812947f6b0c1c318a3f9553f5600dd.jpg -> train_image_212.jpg
# Renamed: X51005705760_jpg.rf.90812947f6b0c1c318a3f9553f5600dd.xml -> train_label_212.xml
# Filtered and updated XML: train_label_212.xml
# Renamed: X51005705804-1-_jpg.rf.1019b315e067a716b7f8aec45997df18.jpg -> train_image_213.jpg
# Renamed: X51005705804-1-_jpg.rf.1019b315e067a716b7f8aec45997df18.xml -> train_label_213.xml
# Filtered and updated XML: train_label_213.xml
# Renamed: X51005711401-1-_jpg.rf.51ab5c38da1f365e460acafd00b99392.jpg -> train_image_214.jpg
# Renamed: X51005711401-1-_jpg.rf.51ab5c38da1f365e460acafd00b99392.xml -> train_label_214.xml
# Filtered and updated XML: train_label_214.xml
# Renamed: X51005711403-1-_jpg.rf.5b397a67d4a0cc3c7f265a0160447fe4.jpg -> train_image_215.jpg
# Renamed: X51005711403-1-_jpg.rf.5b397a67d4a0cc3c7f265a0160447fe4.xml -> train_label_215.xml
# Filtered and updated XML: train_label_215.xml
# Renamed: X51005711404-1-_jpg.rf.8d90f4b133c1eec91c191dafaa6c65b2.jpg -> train_image_216.jpg
# Renamed: X51005711404-1-_jpg.rf.8d90f4b133c1eec91c191dafaa6c65b2.xml -> train_label_216.xml
# Filtered and updated XML: train_label_216.xml
# Renamed: X51005711441_jpg.rf.7bb7b972ff89e3b61055d8c7da9a8406.jpg -> train_image_217.jpg
# Renamed: X51005711441_jpg.rf.7bb7b972ff89e3b61055d8c7da9a8406.xml -> train_label_217.xml
# Filtered and updated XML: train_label_217.xml
# Renamed: X51005711442_jpg.rf.eb068f98807eb1cc315e6c677aefad24.jpg -> train_image_218.jpg
# Renamed: X51005711442_jpg.rf.eb068f98807eb1cc315e6c677aefad24.xml -> train_label_218.xml
# Filtered and updated XML: train_label_218.xml
# Renamed: X51005711445_jpg.rf.36e7b28b2910c49ed79c575a57d18ce6.jpg -> train_image_219.jpg
# Renamed: X51005711445_jpg.rf.36e7b28b2910c49ed79c575a57d18ce6.xml -> train_label_219.xml
# Filtered and updated XML: train_label_219.xml
# Renamed: X51005711447_jpg.rf.44660c5e753c9cefcbe8ea5918d8b3fd.jpg -> train_image_220.jpg
# Renamed: X51005711447_jpg.rf.44660c5e753c9cefcbe8ea5918d8b3fd.xml -> train_label_220.xml
# Filtered and updated XML: train_label_220.xml
# Renamed: X51005711451_jpg.rf.d88f6ea13dc8393debef3d2353729ab4.jpg -> train_image_221.jpg
# Renamed: X51005711451_jpg.rf.d88f6ea13dc8393debef3d2353729ab4.xml -> train_label_221.xml
# Filtered and updated XML: train_label_221.xml
# Renamed: X51005711452_jpg.rf.3fdc618d6a94197a19be014b09ff56cd.jpg -> train_image_222.jpg
# Renamed: X51005711452_jpg.rf.3fdc618d6a94197a19be014b09ff56cd.xml -> train_label_222.xml
# Filtered and updated XML: train_label_222.xml
# Renamed: X51005711453_jpg.rf.a68f138e7cdce427d95f9c4f7d5af2f2.jpg -> train_image_223.jpg
# Renamed: X51005711453_jpg.rf.a68f138e7cdce427d95f9c4f7d5af2f2.xml -> train_label_223.xml
# Filtered and updated XML: train_label_223.xml
# Renamed: X51005711454-1-_jpg.rf.8c5ef8b01d89e9f1629fdbd84e2c9326.jpg -> train_image_224.jpg
# ...
# Filtered and updated XML: valid_label_108.xml
# Renamed: X51006556596_jpg.rf.37d12d4aef814e201efa625b444f479d.jpg -> valid_image_109.jpg
# Renamed: X51006556596_jpg.rf.37d12d4aef814e201efa625b444f479d.xml -> valid_label_109.xml
# Filtered and updated XML: valid_label_109.xml
# Renamed: X51006556604_jpg.rf.eed62a395a8fa238302a4641904283d9.jpg -> valid_image_110.jpg
# Renamed: X51006556604_jpg.rf.eed62a395a8fa238302a4641904283d9.xml -> valid_label_110.xml
# Filtered and updated XML: valid_label_110.xml
# Renamed: X51006556646_jpg.rf.1eb314d5508ec6e73dbabf3588dcf473.jpg -> valid_image_111.jpg
# Renamed: X51006556646_jpg.rf.1eb314d5508ec6e73dbabf3588dcf473.xml -> valid_label_111.xml
# Filtered and updated XML: valid_label_111.xml
# Renamed: X51006556656_jpg.rf.922acf4579ab1d4b00721583e23409e1.jpg -> valid_image_112.jpg
# Renamed: X51006556656_jpg.rf.922acf4579ab1d4b00721583e23409e1.xml -> valid_label_112.xml
# Filtered and updated XML: valid_label_112.xml
# Renamed: X51006556825_jpg.rf.0d4b8b3fe5fddab4f5997ded6bdd3e9e.jpg -> valid_image_113.jpg
# Renamed: X51006556825_jpg.rf.0d4b8b3fe5fddab4f5997ded6bdd3e9e.xml -> valid_label_113.xml
# Filtered and updated XML: valid_label_113.xml
# Renamed: X51006556838-1-_jpg.rf.164c5bf6ee611f100c6efc26428cadfb.jpg -> valid_image_114.jpg
# Renamed: X51006556838-1-_jpg.rf.164c5bf6ee611f100c6efc26428cadfb.xml -> valid_label_114.xml
# Filtered and updated XML: valid_label_114.xml
# Renamed: X51006556839-1-_jpg.rf.597784aedbee989584f416088d54c16e.jpg -> valid_image_115.jpg
# Renamed: X51006556839-1-_jpg.rf.597784aedbee989584f416088d54c16e.xml -> valid_label_115.xml
# Filtered and updated XML: valid_label_115.xml
# Renamed: X51006556840-1-_jpg.rf.e7d65b0ffb60b8a4dc0d505a6cd1824b.jpg -> valid_image_116.jpg
# Renamed: X51006556840-1-_jpg.rf.e7d65b0ffb60b8a4dc0d505a6cd1824b.xml -> valid_label_116.xml
# Filtered and updated XML: valid_label_116.xml
# Renamed: X51006556861_jpg.rf.a8a6c990258db24144467382ebf2eec2.jpg -> valid_image_117.jpg
# Renamed: X51006556861_jpg.rf.a8a6c990258db24144467382ebf2eec2.xml -> valid_label_117.xml
# Filtered and updated XML: valid_label_117.xml
# Renamed: X51006557164_jpg.rf.0f080c7060d6ac0f300923d184d388b9.jpg -> valid_image_118.jpg
# Renamed: X51006557164_jpg.rf.0f080c7060d6ac0f300923d184d388b9.xml -> valid_label_118.xml
# Filtered and updated XML: valid_label_118.xml
# Renamed: X51006557188_jpg.rf.7ffab15ab186cc3da3c1822e2281921b.jpg -> valid_image_119.jpg
# Renamed: X51006557188_jpg.rf.7ffab15ab186cc3da3c1822e2281921b.xml -> valid_label_119.xml
# Filtered and updated XML: valid_label_119.xml
# Renamed: X51006557193-1-_jpg.rf.927c3a874445ae4803ca8c36a93f6846.jpg -> valid_image_120.jpg
# Renamed: X51006557193-1-_jpg.rf.927c3a874445ae4803ca8c36a93f6846.xml -> valid_label_120.xml
# Filtered and updated XML: valid_label_120.xml
# Renamed: X51006557213_jpg.rf.da31e8109db7206ce0d1aece42fc4297.jpg -> valid_image_121.jpg
# Renamed: X51006557213_jpg.rf.da31e8109db7206ce0d1aece42fc4297.xml -> valid_label_121.xml
# Filtered and updated XML: valid_label_121.xml
# Renamed: X51006557508_jpg.rf.d1f79f6f68c670b02cb24c767180085f.jpg -> valid_image_122.jpg
# Renamed: X51006557508_jpg.rf.d1f79f6f68c670b02cb24c767180085f.xml -> valid_label_122.xml
# Filtered and updated XML: valid_label_122.xml
# Renamed: X51006619341_jpg.rf.028e6ac31ed93d7ae1056c0fd4d9a795.jpg -> valid_image_123.jpg
# Renamed: X51006619341_jpg.rf.028e6ac31ed93d7ae1056c0fd4d9a795.xml -> valid_label_123.xml
# Filtered and updated XML: valid_label_123.xml
# Renamed: X51006619342_jpg.rf.1484e679e49ebce04219e6eb8a4931bb.jpg -> valid_image_124.jpg
# Renamed: X51006619342_jpg.rf.1484e679e49ebce04219e6eb8a4931bb.xml -> valid_label_124.xml
# Filtered and updated XML: valid_label_124.xml
# Renamed: X51006619343_jpg.rf.3f5d64753531ec8522d326a165d94801.jpg -> valid_image_125.jpg
# Renamed: X51006619343_jpg.rf.3f5d64753531ec8522d326a165d94801.xml -> valid_label_125.xml
# Filtered and updated XML: valid_label_125.xml
# Renamed: X51006619550_jpg.rf.712454da4211ebc15543622035b0d317.jpg -> valid_image_126.jpg
# Renamed: X51006619550_jpg.rf.712454da4211ebc15543622035b0d317.xml -> valid_label_126.xml
# Filtered and updated XML: valid_label_126.xml
# Renamed: X51006619561_jpg.rf.9d70b44cd554e55730896ad089fdf1b7.jpg -> valid_image_127.jpg
# Renamed: X51006619561_jpg.rf.9d70b44cd554e55730896ad089fdf1b7.xml -> valid_label_127.xml
# Filtered and updated XML: valid_label_127.xml
# Renamed: X51006619709_jpg.rf.7a7e7dd2baf59988fad9ac31eb4ceac8.jpg -> valid_image_128.jpg
# Renamed: X51006619709_jpg.rf.7a7e7dd2baf59988fad9ac31eb4ceac8.xml -> valid_label_128.xml
# Filtered and updated XML: valid_label_128.xml
# Renamed: X51006619783_jpg.rf.3efd108abcaaa1a2cfab70cbd2c13bf6.jpg -> valid_image_129.jpg
# Renamed: X51006619783_jpg.rf.3efd108abcaaa1a2cfab70cbd2c13bf6.xml -> valid_label_129.xml
# Filtered and updated XML: valid_label_129.xml
# Renamed: X51006619862_jpg.rf.fe48026b12eb8033333f6693868d70fb.jpg -> valid_image_130.jpg
# Renamed: X51006619862_jpg.rf.fe48026b12eb8033333f6693868d70fb.xml -> valid_label_130.xml
# Filtered and updated XML: valid_label_130.xml
# Renamed: X51006620181_jpg.rf.126a7f104f36ed92adb65426b49c615e.jpg -> valid_image_131.jpg
# Renamed: X51006620181_jpg.rf.126a7f104f36ed92adb65426b49c615e.xml -> valid_label_131.xml
# Filtered and updated XML: valid_label_131.xml
# Renamed: X51006620189_jpg.rf.bab72519fea7ed4214d7cb8840ebcc51.jpg -> valid_image_132.jpg
# Renamed: X51006620189_jpg.rf.bab72519fea7ed4214d7cb8840ebcc51.xml -> valid_label_132.xml
# Filtered and updated XML: valid_label_132.xml
# Renamed: X51006647932_jpg.rf.ace8375437e838937b17662e3178117e.jpg -> valid_image_133.jpg
# Renamed: X51006647932_jpg.rf.ace8375437e838937b17662e3178117e.xml -> valid_label_133.xml
# Filtered and updated XML: valid_label_133.xml
# Renamed: X51006857265_jpg.rf.ab51f145cbdf7847374d0144814e4af8.jpg -> valid_image_134.jpg
# Renamed: X51006857265_jpg.rf.ab51f145cbdf7847374d0144814e4af8.xml -> valid_label_134.xml
# Filtered and updated XML: valid_label_134.xml
# Renamed: X51006867436_jpg.rf.c4d7d9e08562540e4c43c9fa61b46cde.jpg -> valid_image_135.jpg
# Renamed: X51006867436_jpg.rf.c4d7d9e08562540e4c43c9fa61b46cde.xml -> valid_label_135.xml
# Filtered and updated XML: valid_label_135.xml
# Renamed: X51006882603_jpg.rf.df2101bfe6466c512ab7c5c203bb7e3b.jpg -> valid_image_136.jpg
# Renamed: X51006882603_jpg.rf.df2101bfe6466c512ab7c5c203bb7e3b.xml -> valid_label_136.xml
# Filtered and updated XML: valid_label_136.xml
# Renamed: X51006913023_jpg.rf.a51edac9ac0a979d09a2491e282f3ff0.jpg -> valid_image_137.jpg
# Renamed: X51006913023_jpg.rf.a51edac9ac0a979d09a2491e282f3ff0.xml -> valid_label_137.xml
# Filtered and updated XML: valid_label_137.xml
# Renamed: X51007103599_jpg.rf.00d971f669f9758504b1338bc284c48e.jpg -> valid_image_138.jpg
# Renamed: X51007103599_jpg.rf.00d971f669f9758504b1338bc284c48e.xml -> valid_label_138.xml
# Filtered and updated XML: valid_label_138.xml
# Renamed: X51007103643_jpg.rf.be42db186f2027ce89f7e3375a21d292.jpg -> valid_image_139.jpg
# Renamed: X51007103643_jpg.rf.be42db186f2027ce89f7e3375a21d292.xml -> valid_label_139.xml
# Filtered and updated XML: valid_label_139.xml
# Renamed: X51007103675_jpg.rf.28b26e5d616cf568cdd841062a37d5a1.jpg -> valid_image_140.jpg
# Renamed: X51007103675_jpg.rf.28b26e5d616cf568cdd841062a37d5a1.xml -> valid_label_140.xml
# Filtered and updated XML: valid_label_140.xml
# Renamed: X51007103688_jpg.rf.a677b7effc5864d53bbf5ce5f538d7c6.jpg -> valid_image_141.jpg
# Renamed: X51007103688_jpg.rf.a677b7effc5864d53bbf5ce5f538d7c6.xml -> valid_label_141.xml
# Filtered and updated XML: valid_label_141.xml
# Renamed: X51007225398_jpg.rf.94e99596101e600fb85aa18852d5564b.jpg -> valid_image_142.jpg
# Renamed: X51007225398_jpg.rf.94e99596101e600fb85aa18852d5564b.xml -> valid_label_142.xml
# Filtered and updated XML: valid_label_142.xml
# Renamed: X51007231365_jpg.rf.8e1d0239ea968ecb31ee9c0a459d34b4.jpg -> valid_image_143.jpg
# Renamed: X51007231365_jpg.rf.8e1d0239ea968ecb31ee9c0a459d34b4.xml -> valid_label_143.xml
# Filtered and updated XML: valid_label_143.xml
# Renamed: X51007262330_jpg.rf.e6208d026f4ddf921f72031983aec245.jpg -> valid_image_144.jpg
# Renamed: X51007262330_jpg.rf.e6208d026f4ddf921f72031983aec245.xml -> valid_label_144.xml
# Filtered and updated XML: valid_label_144.xml
# Renamed: X51007339097_jpg.rf.c7dc5466ad20f3eee4e1056ae5083538.jpg -> valid_image_145.jpg
# Renamed: X51007339097_jpg.rf.c7dc5466ad20f3eee4e1056ae5083538.xml -> valid_label_145.xml
# Filtered and updated XML: valid_label_145.xml
# Renamed: X51007339131_jpg.rf.740381dc7f12dea9025c10b54e91d478.jpg -> valid_image_146.jpg
# Renamed: X51007339131_jpg.rf.740381dc7f12dea9025c10b54e91d478.xml -> valid_label_146.xml
# Filtered and updated XML: valid_label_146.xml
# Renamed: X51007339135_jpg.rf.d2726b24645f02e4410afded0135b88a.jpg -> valid_image_147.jpg
# Renamed: X51007339135_jpg.rf.d2726b24645f02e4410afded0135b88a.xml -> valid_label_147.xml
# Filtered and updated XML: valid_label_147.xml
# Renamed: X51007339136_jpg.rf.28f7c29f4266eae79eba07140426bd5d.jpg -> valid_image_148.jpg
# Renamed: X51007339136_jpg.rf.28f7c29f4266eae79eba07140426bd5d.xml -> valid_label_148.xml
# Filtered and updated XML: valid_label_148.xml
# Renamed: X51007339152_jpg.rf.70a35f0cf6ae05e049d6d22e0801bffb.jpg -> valid_image_149.jpg
# Renamed: X51007339152_jpg.rf.70a35f0cf6ae05e049d6d22e0801bffb.xml -> valid_label_149.xml
# Filtered and updated XML: valid_label_149.xml
# Renamed: X51007339157-1-_jpg.rf.103349483e4387ef2f556610b60f79d2.jpg -> valid_image_150.jpg
# Renamed: X51007339157-1-_jpg.rf.103349483e4387ef2f556610b60f79d2.xml -> valid_label_150.xml
# Filtered and updated XML: valid_label_150.xml
# Renamed: X51007339639-1-_jpg.rf.ca0449d6c5e6aef2aa0635df06b1dddf.jpg -> valid_image_151.jpg
# Renamed: X51007339639-1-_jpg.rf.ca0449d6c5e6aef2aa0635df06b1dddf.xml -> valid_label_151.xml
# Filtered and updated XML: valid_label_151.xml
# Renamed: X51007339642-1-_jpg.rf.a585c219081650f4760f021d0dee1a4e.jpg -> valid_image_152.jpg
# Renamed: X51007339642-1-_jpg.rf.a585c219081650f4760f021d0dee1a4e.xml -> valid_label_152.xml
# Filtered and updated XML: valid_label_152.xml
# Renamed: X51007339643-1-_jpg.rf.c7cfe2105b94d21281acc883a6ef8ec7.jpg -> valid_image_153.jpg
# Renamed: X51007339643-1-_jpg.rf.c7cfe2105b94d21281acc883a6ef8ec7.xml -> valid_label_153.xml
# Filtered and updated XML: valid_label_153.xml
# Renamed: X51007339647_jpg.rf.4630ca4a22515f9be16ee41dc1df56a2.jpg -> valid_image_154.jpg
# Renamed: X51007339647_jpg.rf.4630ca4a22515f9be16ee41dc1df56a2.xml -> valid_label_154.xml
# Filtered and updated XML: valid_label_154.xml
# Renamed: X51007339653-1-_jpg.rf.70f4974bd80f8db5915fa8ea479d3dcc.jpg -> valid_image_155.jpg
# Renamed: X51007339653-1-_jpg.rf.70f4974bd80f8db5915fa8ea479d3dcc.xml -> valid_label_155.xml
# Filtered and updated XML: valid_label_155.xml
# Renamed: X51007579726_jpg.rf.4ed9994c9ee1e2f991b11226a780afd0.jpg -> valid_image_156.jpg
# Renamed: X51007579726_jpg.rf.4ed9994c9ee1e2f991b11226a780afd0.xml -> valid_label_156.xml
# Filtered and updated XML: valid_label_156.xml
# Renamed: X51007846301_jpg.rf.2387dda6770f1400e1ae2913a53cbf68.jpg -> valid_image_157.jpg
# Renamed: X51007846301_jpg.rf.2387dda6770f1400e1ae2913a53cbf68.xml -> valid_label_157.xml
# Filtered and updated XML: valid_label_157.xml
# Renamed: X51007846350_jpg.rf.70b94ffaddec2cef6557f0b03f9f0ce0.jpg -> valid_image_158.jpg
# Renamed: X51007846350_jpg.rf.70b94ffaddec2cef6557f0b03f9f0ce0.xml -> valid_label_158.xml
# Filtered and updated XML: valid_label_158.xml
# Renamed: X51007846393_jpg.rf.a2e6befb2873b6bb35b418067ee7bc1c.jpg -> valid_image_159.jpg
# Renamed: X51007846393_jpg.rf.a2e6befb2873b6bb35b418067ee7bc1c.xml -> valid_label_159.xml
# Filtered and updated XML: valid_label_159.xml
# Renamed: X51008030566_jpg.rf.fec9af51d146bae94825dacf62cb0d92.jpg -> valid_image_160.jpg
# Renamed: X51008030566_jpg.rf.fec9af51d146bae94825dacf62cb0d92.xml -> valid_label_160.xml
# Filtered and updated XML: valid_label_160.xml
# Renamed: X51008042783_jpg.rf.4a88871f984e0a018445ee8e2ac376ec.jpg -> valid_image_161.jpg
# Renamed: X51008042783_jpg.rf.4a88871f984e0a018445ee8e2ac376ec.xml -> valid_label_161.xml
# Filtered and updated XML: valid_label_161.xml
# Renamed: X51008042791_jpg.rf.2b4392603c4855509e9b751110f1ad87.jpg -> valid_image_162.jpg
# Renamed: X51008042791_jpg.rf.2b4392603c4855509e9b751110f1ad87.xml -> valid_label_162.xml
# Filtered and updated XML: valid_label_162.xml
# Renamed: X51008042793_jpg.rf.3bb261ac4d510707debfda50100c84a7.jpg -> valid_image_163.jpg
# Renamed: X51008042793_jpg.rf.3bb261ac4d510707debfda50100c84a7.xml -> valid_label_163.xml
# Filtered and updated XML: valid_label_163.xml
# Renamed: X51008099043_jpg.rf.8bb7ec5a3c93c804b130ae0cd7cb297d.jpg -> valid_image_164.jpg
# Renamed: X51008099043_jpg.rf.8bb7ec5a3c93c804b130ae0cd7cb297d.xml -> valid_label_164.xml
# Filtered and updated XML: valid_label_164.xml
# Renamed: X51008099054_jpg.rf.95a703bd3a7cc8ad692a03eddf4eecb1.jpg -> valid_image_165.jpg
# Renamed: X51008099054_jpg.rf.95a703bd3a7cc8ad692a03eddf4eecb1.xml -> valid_label_165.xml
# Filtered and updated XML: valid_label_165.xml
# Renamed: X51008099083_jpg.rf.f2b03e74f201b59ef2c98a2965faa3e9.jpg -> valid_image_166.jpg
# Renamed: X51008099083_jpg.rf.f2b03e74f201b59ef2c98a2965faa3e9.xml -> valid_label_166.xml
# Filtered and updated XML: valid_label_166.xml
# Renamed: X51008099089_jpg.rf.593f76ee32aaae225287fc6b7aba7e15.jpg -> valid_image_167.jpg
# Renamed: X51008099089_jpg.rf.593f76ee32aaae225287fc6b7aba7e15.xml -> valid_label_167.xml
# Filtered and updated XML: valid_label_167.xml
# Renamed: X51008114216_jpg.rf.38ff2072db51bca1ba0ca34cbe8a0cf7.jpg -> valid_image_168.jpg
# Renamed: X51008114216_jpg.rf.38ff2072db51bca1ba0ca34cbe8a0cf7.xml -> valid_label_168.xml
# Filtered and updated XML: valid_label_168.xml
# Renamed: X51008114266_jpg.rf.d9a3671a010e3cdfb30328aa22254f1e.jpg -> valid_image_169.jpg
# Renamed: X51008114266_jpg.rf.d9a3671a010e3cdfb30328aa22254f1e.xml -> valid_label_169.xml
# Filtered and updated XML: valid_label_169.xml
# Renamed: X51008114282_jpg.rf.81a8d420077b94cc0a90a71415017666.jpg -> valid_image_170.jpg
# Renamed: X51008114282_jpg.rf.81a8d420077b94cc0a90a71415017666.xml -> valid_label_170.xml
# Filtered and updated XML: valid_label_170.xml
# Renamed: X51008114321_jpg.rf.a9b4b31a7ca486c47f4ca7caed96ea37.jpg -> valid_image_171.jpg
# Renamed: X51008114321_jpg.rf.a9b4b31a7ca486c47f4ca7caed96ea37.xml -> valid_label_171.xml
# Filtered and updated XML: valid_label_171.xml
# Renamed: X51008142030_jpg.rf.1c788b4b1a30582adaed26cdd6bd6a77.jpg -> valid_image_172.jpg
# Renamed: X51008142030_jpg.rf.1c788b4b1a30582adaed26cdd6bd6a77.xml -> valid_label_172.xml
# Filtered and updated XML: valid_label_172.xml
# Renamed: X51008142033_jpg.rf.95dc40965050fa9b0f9a820ede71c178.jpg -> valid_image_173.jpg
# Renamed: X51008142033_jpg.rf.95dc40965050fa9b0f9a820ede71c178.xml -> valid_label_173.xml
# Filtered and updated XML: valid_label_173.xml
# Renamed: X51008142038_jpg.rf.229ab6b5fe0ca94fcb87c64f3d26d4b1.jpg -> valid_image_174.jpg
# Renamed: X51008142038_jpg.rf.229ab6b5fe0ca94fcb87c64f3d26d4b1.xml -> valid_label_174.xml
# Filtered and updated XML: valid_label_174.xml
# Renamed: X51008142059_jpg.rf.364e13963d620880217bb6d0374aa4a1.jpg -> valid_image_175.jpg
# Renamed: X51008142059_jpg.rf.364e13963d620880217bb6d0374aa4a1.xml -> valid_label_175.xml
# Filtered and updated XML: valid_label_175.xml
# Renamed: temp_struk5_jpg.rf.703855544b0317c51631c49038057eb9.jpg -> valid_image_176.jpg
# Renamed: temp_struk5_jpg.rf.703855544b0317c51631c49038057eb9.xml -> valid_label_176.xml
# Filtered and updated XML: valid_label_176.xml
# Renamed: temp_struk6_jpg.rf.e917a4dd95cc29d76f180ce7588cb93d.jpg -> valid_image_177.jpg
# Renamed: temp_struk6_jpg.rf.e917a4dd95cc29d76f180ce7588cb93d.xml -> valid_label_177.xml
# Filtered and updated XML: valid_label_177.xml
# Renamed: temp_struk7_jpg.rf.a522851d18a2182728b6c41fa5d2281c.jpg -> valid_image_178.jpg
# Renamed: temp_struk7_jpg.rf.a522851d18a2182728b6c41fa5d2281c.xml -> valid_label_178.xml
# Filtered and updated XML: valid_label_178.xml
# Renamed: temp_struk_jpg.rf.7f7ab61549530a84aa1590e16c92919b.jpg -> valid_image_179.jpg
# Renamed: temp_struk_jpg.rf.7f7ab61549530a84aa1590e16c92919b.xml -> valid_label_179.xml
# Filtered and updated XML: valid_label_179.xml

# %%
import os
import shutil
import xml.etree.ElementTree as ET

invalid_dir = os.path.join(extract_dir, "incorrect_annotations")
folders_to_check = ["train", "valid"]

# Pastikan folder tujuan ada
os.makedirs(invalid_dir, exist_ok=True)

# Ekstensi file gambar yang diharapkan
image_extensions = {".jpg", ".jpeg", ".png"}

def validate_and_move(xml_file_path, folder_path):
    try:
        # Parse file XML
        tree = ET.parse(xml_file_path)
        root = tree.getroot()
        
        # Ambil nama file gambar dari tag <filename>
        image_file_name = root.find('filename').text
        image_file_path = os.path.join(folder_path, image_file_name)

        # Ambil semua class dalam file XML
        classes_in_file = [obj.find('name').text for obj in root.findall('object')]

        # Validasi class dalam file XML
        for obj in root.findall('object'):
            class_name = obj.find('name').text
            if class_name not in allowed_labels:
                print(f"Invalid annotation found in: {xml_file_path}, class: {class_name}")
                # Pindahkan file XML dan gambar
                move_files(xml_file_path, image_file_path)
                return
        
        # Pastikan semua class yang diizinkan ada
        if not all(cls in classes_in_file for cls in allowed_labels):
            print(f"Missing required classes in: {xml_file_path}")
            move_files(xml_file_path, image_file_path)

    except ET.ParseError:
        print(f"Error parsing XML file: {xml_file_path}. Moving to incorrect folder.")
        move_files(xml_file_path, None)
    except Exception as e:
        print(f"Unexpected error: {e}")

def move_files(xml_file_path, image_file_path):
    """Pindahkan file XML dan gambar ke folder incorrect_annotations."""
    # Pindahkan file XML
    shutil.move(xml_file_path, os.path.join(invalid_dir, os.path.basename(xml_file_path)))
    print(f"Moved XML: {os.path.basename(xml_file_path)} -> {invalid_dir}")

    # Pindahkan file gambar jika ada
    if image_file_path and os.path.exists(image_file_path):
        shutil.move(image_file_path, os.path.join(invalid_dir, os.path.basename(image_file_path)))
        print(f"Moved Image: {os.path.basename(image_file_path)} -> {invalid_dir}")
    elif image_file_path:
        print(f"Image file not found: {image_file_path}")

# Iterasi semua folder yang akan diperiksa
for folder in folders_to_check:
    folder_path = os.path.join(base_dir, folder)
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} tidak ditemukan. Melewati folder ini.")
        continue

    # Iterasi semua file XML di dalam folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if file_name.endswith('.xml') and os.path.isfile(file_path):
            validate_and_move(file_path, folder_path)

print("Proses validasi dan pemindahan selesai.")
# Out:
# Missing required classes in: dataset\train\train_label_162.xml
# Moved XML: train_label_162.xml -> dataset\incorrect_annotations
# Moved Image: train_image_162.jpg -> dataset\incorrect_annotations
# Missing required classes in: dataset\valid\valid_label_51.xml
# Moved XML: valid_label_51.xml -> dataset\incorrect_annotations
# Moved Image: valid_image_51.jpg -> dataset\incorrect_annotations
# Proses validasi dan pemindahan selesai.
